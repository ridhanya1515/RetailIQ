# %% [markdown]
# # RetailIQ - Exploratory Data Analysis & Modeling Notebook
# This notebook demonstrates exploratory data analysis, RFM segmentation, and demand forecasting experiments on the UCI Online Retail dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel('../data/raw/OnlineRetail.xlsx')
print(f"Raw dataset shape: {df.shape}")
df.head()
